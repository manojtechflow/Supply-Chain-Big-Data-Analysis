# %%
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
file_path  = './Datasets/DataCoSupplyChainDataset.csv'
supply_dataset = pd.read_csv(file_path,encoding='ISO-8859-1', header=0)

# %%
supply_dataset.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
supply_dataset.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
supply_dataset['Market'].value_counts()
# Out:
# LATAM           51594
# Europe          50252
# Pacific Asia    41260
# USCA            25799
# Africa          11614
# Name: Market, dtype: int64

# %%
# Dropping columns with less importance

supply_dataset.drop(['Customer Email','Customer Password','Order Zipcode','Product Description','Product Image'], axis = 1, inplace=True)

# %%
supply_dataset.head(3)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
#
#   Customer Country Customer Fname  Customer Id Customer Lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# ...

# %%
# checking null values in columns, viewing only columns with null vales
supply_dataset.isna().sum()[supply_dataset.isna().sum() != 0 ]
# Out:
# Customer Lname      8
# Customer Zipcode    3
# dtype: int64

# %%
# shape of the dataset

supply_dataset.shape
# Out:
# (180519, 48)

# %%
#creating Dimension table for Market

marketsDim = supply_dataset['Market'].unique()
marketsDim = pd.DataFrame(marketsDim, columns = ['Market'])
marketsDim['Market_Id'] = marketsDim.index
marketsDim
# Out:
#          Market  Market_Id
# 0  Pacific Asia          0
# 1          USCA          1
# 2        Africa          2
# 3        Europe          3
# 4         LATAM          4

# %%
# Creating Dimension table for Delivery Status
DeliveryStatusDim = supply_dataset['Delivery Status'].unique()
DeliveryStatusDim = pd.DataFrame(DeliveryStatusDim, columns=['Delivery Status'])
DeliveryStatusDim['Del_Status_Id'] = DeliveryStatusDim.index
DeliveryStatusDim
# Out:
#      Delivery Status  Del_Status_Id
# 0   Advance shipping              0
# 1      Late delivery              1
# 2   Shipping on time              2
# 3  Shipping canceled              3

# %%
ShippingModeDim = supply_dataset['Shipping Mode'].unique()
ShippingModeDim = pd.DataFrame(ShippingModeDim, columns=['Shipping Mode'])
ShippingModeDim['Ship_Mode_id'] = ShippingModeDim.index
ShippingModeDim
# Out:
#     Shipping Mode  Ship_Mode_id
# 0  Standard Class             0
# 1     First Class             1
# 2    Second Class             2
# 3        Same Day             3

# %%
CustomerCountryDim = supply_dataset['Customer Country'].unique()
